# %%
import numpy as np
import torch
from PIL import Image
from torchvision import models

# %%
DATASET_PATH = '../dataset/petfinder-adoption-prediction/'

# %%
resnet50 = models.resnet50(pretrained=True)

# %%
def read_image_paths(dataset_dir):
    return image_paths, labels

# %%
def read_image_generator():
    # do image net preprocessing

# %%
img = Image.open("/Users/sergei/Documents/Projects/datasets/petfinder-pawpularity-score/train/0117f444e6118619c4f6492cba703177.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=738x960 at 0x137F94CD0>

# %%
img = np.array(img)
